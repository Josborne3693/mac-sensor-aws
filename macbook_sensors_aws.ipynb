# %%
import subprocess
import time
import json
import csv
import os

try:
    import boto3
except:
    print("AWS Python SDK 'boto3' not installed")

# %%
def getTime(verbose=True):
    currentTime = time.time()
    if verbose == True: 
        print(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(currentTime)))
    return currentTime

# %%
def getCPUtemp():
    cpuTemp = 0.0
    
    cpuBashCommand = "istats cpu --value-only"
    process = subprocess.Popen(cpuBashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    
    if error == None:
        cpuTemp = float(output.decode('UTF-8').strip())
    else:
        print("Error getting cpu temperature")
        
    return cpuTemp

# %%
def getFanSpeeds():
    fanSpeedsData = []
    fanSpeeds = []
    
    cpuBashCommand = "istats fan --value-only"
    process = subprocess.Popen(cpuBashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    
    if error == None:
        fanSpeedsData = output.decode('UTF-8').strip().split('\n')
        for i, value in enumerate(fanSpeedsData):
            fanSpeedsData[i] = value.strip()
        numFans = int(fanSpeedsData[0])
        for i in range(numFans):
            fanSpeeds.append(int(fanSpeedsData[i+1]))
        
        # print("Num fans: " + str(numFans))
    else:
        print("Error getting fan 1 speed")
        
    return fanSpeeds

# %%
def gatherData():
    """Gathers time, cpuTemp, and fanSpeed data"""
    data = {
        "timestamp": 0,
        "cpuTemp": 0,
        "fan1speed": 0,
        "fan2speed": 0
    }
    
    currentTime = getTime(verbose=True)
    cpuTemp = getCPUtemp()
    fanSpeeds = getFanSpeeds()
    
    data['timestamp'] = currentTime
    data['cpuTemp'] = cpuTemp
    data['fan1speed'] = fanSpeeds[0]
    data['fan2speed'] = fanSpeeds[1]
    
    return data

# %%
def sendData(client, data):
    message = {
        'messageId': "j_macbook",
        'payload': str.encode(json.dumps(data))
    }
    response = client.batch_put_message(
        channelName="macbook_sensors_channel",
        messages=[message]
    )
    print(response)

# %%
def writeDictToCSV(csv_file, dict_data):
    csv_columns = list(dict_data.keys())
    
    # if file exists and is not empty, append, else write
    if os.path.isfile(csv_file): # file exists
        if os.stat(csv_file).st_size > 0: # file is not empty
            writeMethod = 'a'
        else:
            writeMethod = 'w'
    else:
        writeMethod = 'w'
        
    try:
        with open(csv_file, writeMethod) as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            if writeMethod == 'w':
                writer.writeheader()
            writer.writerow(dict_data)
    except IOError:
        print("I/O error")

# %%
def collectData(
    seconds,
    frequency,
    sendToIoTAnalytics=False,
    saveToCSV=False,
    csv_file=None,
    verbose=False
):
    
    client = boto3.client('iotanalytics')
    
    sleepTime = 1.0/frequency
    iterations = int(seconds/sleepTime)
    
    starttime=time.time()
    
    for i in range(iterations):
        data = gatherData()
        
        if sendToIoTAnalytics == True:
            sendData(client=client, data=data)
        
        if saveToCSV == True:
            if csv_file == None:
                csv_file = "data_log_" + time.strftime('%Y-%m-%d--%H-%M-%S', time.localtime(time.time())) + ".csv"
 
            writeDictToCSV(
                csv_file=csv_file,
                dict_data=data
            )
        
        if verbose == True:
            print(json.dumps(data, indent=2))
            
        time.sleep(sleepTime - ((time.time() - starttime) % sleepTime))

# %%
#csv_file = "data_log_2019-02-28--11-31-40.csv"
csv_file = None

collectData(
    seconds=60,
    frequency=2,
    sendToIoTAnalytics=False,
    saveToCSV=True,
    csv_file=csv_file,
    verbose=True
)
# Out:
# 2019-02-28 12:33:10
# {
#   "timestamp": 1551375190.773056,
#   "cpuTemp": 52.56,
#   "fan1speed": 2159,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:11
# {
#   "timestamp": 1551375191.2748191,
#   "cpuTemp": 52.56,
#   "fan1speed": 2155,
#   "fan2speed": 1993
# }
# 2019-02-28 12:33:11
# {
#   "timestamp": 1551375191.778325,
#   "cpuTemp": 52.5,
#   "fan1speed": 2147,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:12
# {
#   "timestamp": 1551375192.274824,
#   "cpuTemp": 52.5,
#   "fan1speed": 2155,
#   "fan2speed": 2002
# }
# 2019-02-28 12:33:12
# {
#   "timestamp": 1551375192.773152,
#   "cpuTemp": 52.63,
#   "fan1speed": 2155,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:13
# {
#   "timestamp": 1551375193.2746391,
#   "cpuTemp": 52.63,
#   "fan1speed": 2155,
#   "fan2speed": 2006
# }
# 2019-02-28 12:33:13
# {
#   "timestamp": 1551375193.7776482,
#   "cpuTemp": 52.69,
#   "fan1speed": 2155,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:14
# {
#   "timestamp": 1551375194.2775612,
#   "cpuTemp": 52.69,
#   "fan1speed": 2155,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:14
# {
#   "timestamp": 1551375194.7733061,
#   "cpuTemp": 52.75,
#   "fan1speed": 2157,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:15
# {
#   "timestamp": 1551375195.278126,
#   "cpuTemp": 52.75,
#   "fan1speed": 2166,
#   "fan2speed": 2005
# }
# 2019-02-28 12:33:15
# {
#   "timestamp": 1551375195.773651,
#   "cpuTemp": 52.94,
#   "fan1speed": 2170,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:16
# {
#   "timestamp": 1551375196.274498,
#   "cpuTemp": 52.94,
#   "fan1speed": 2169,
#   "fan2speed": 1997
# }
# 2019-02-28 12:33:16
# {
#   "timestamp": 1551375196.77427,
#   "cpuTemp": 54.38,
#   "fan1speed": 2169,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:17
# {
#   "timestamp": 1551375197.2755818,
#   "cpuTemp": 54.38,
#   "fan1speed": 2157,
#   "fan2speed": 2003
# }
# 2019-02-28 12:33:17
# {
#   "timestamp": 1551375197.7781298,
#   "cpuTemp": 53.56,
#   "fan1speed": 2155,
#   "fan2speed": 2005
# }
# 2019-02-28 12:33:18
# {
#   "timestamp": 1551375198.2781389,
#   "cpuTemp": 53.56,
#   "fan1speed": 2155,
#   "fan2speed": 2003
# }
# 2019-02-28 12:33:18
# {
#   "timestamp": 1551375198.7781372,
#   "cpuTemp": 53.81,
#   "fan1speed": 2155,
#   "fan2speed": 1995
# }
# 2019-02-28 12:33:19
# {
#   "timestamp": 1551375199.276716,
#   "cpuTemp": 53.81,
#   "fan1speed": 2155,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:19
# {
#   "timestamp": 1551375199.778178,
#   "cpuTemp": 55.06,
#   "fan1speed": 2155,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:20
# {
#   "timestamp": 1551375200.273452,
#   "cpuTemp": 55.06,
#   "fan1speed": 2155,
#   "fan2speed": 2006
# }
# 2019-02-28 12:33:20
# {
#   "timestamp": 1551375200.7746382,
#   "cpuTemp": 55.25,
#   "fan1speed": 2155,
#   "fan2speed": 2006
# }
# 2019-02-28 12:33:21
# {
#   "timestamp": 1551375201.2758489,
#   "cpuTemp": 55.25,
#   "fan1speed": 2160,
#   "fan2speed": 1997
# }
# 2019-02-28 12:33:21
# {
#   "timestamp": 1551375201.777001,
#   "cpuTemp": 55.44,
#   "fan1speed": 2160,
#   "fan2speed": 1993
# }
# 2019-02-28 12:33:22
# {
#   "timestamp": 1551375202.278189,
#   "cpuTemp": 55.44,
#   "fan1speed": 2160,
#   "fan2speed": 1995
# }
# 2019-02-28 12:33:22
# {
#   "timestamp": 1551375202.778124,
#   "cpuTemp": 55.44,
#   "fan1speed": 2160,
#   "fan2speed": 2003
# }
# 2019-02-28 12:33:23
# {
#   "timestamp": 1551375203.2781491,
#   "cpuTemp": 54.69,
#   "fan1speed": 2160,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:23
# {
#   "timestamp": 1551375203.778162,
#   "cpuTemp": 54.69,
#   "fan1speed": 2165,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:24
# {
#   "timestamp": 1551375204.27358,
#   "cpuTemp": 54.88,
#   "fan1speed": 2165,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:24
# {
#   "timestamp": 1551375204.777022,
#   "cpuTemp": 54.88,
#   "fan1speed": 2165,
#   "fan2speed": 2003
# }
# 2019-02-28 12:33:25
# {
#   "timestamp": 1551375205.273599,
#   "cpuTemp": 56.06,
#   "fan1speed": 2164,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:25
# {
#   "timestamp": 1551375205.7781372,
#   "cpuTemp": 56.06,
#   "fan1speed": 2157,
#   "fan2speed": 2002
# }
# 2019-02-28 12:33:26
# {
#   "timestamp": 1551375206.278152,
#   "cpuTemp": 56.31,
#   "fan1speed": 2150,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:26
# {
#   "timestamp": 1551375206.7781272,
#   "cpuTemp": 56.31,
#   "fan1speed": 2150,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:27
# {
#   "timestamp": 1551375207.273603,
#   "cpuTemp": 56.44,
#   "fan1speed": 2157,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:27
# {
#   "timestamp": 1551375207.7781289,
#   "cpuTemp": 56.44,
#   "fan1speed": 2160,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:28
# {
#   "timestamp": 1551375208.278122,
#   "cpuTemp": 55.63,
#   "fan1speed": 2160,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:28
# {
#   "timestamp": 1551375208.773737,
#   "cpuTemp": 55.63,
#   "fan1speed": 2160,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:29
# {
#   "timestamp": 1551375209.275817,
#   "cpuTemp": 55.81,
#   "fan1speed": 2160,
#   "fan2speed": 2003
# }
# 2019-02-28 12:33:29
# {
#   "timestamp": 1551375209.778123,
#   "cpuTemp": 55.81,
#   "fan1speed": 2160,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:30
# {
#   "timestamp": 1551375210.278116,
#   "cpuTemp": 57.0,
#   "fan1speed": 2160,
#   "fan2speed": 2001
# }
# 2019-02-28 12:33:30
# {
#   "timestamp": 1551375210.778121,
#   "cpuTemp": 57.0,
#   "fan1speed": 2160,
#   "fan2speed": 1994
# }
# 2019-02-28 12:33:31
# {
#   "timestamp": 1551375211.274704,
#   "cpuTemp": 57.13,
#   "fan1speed": 2160,
#   "fan2speed": 1996
# }
# 2019-02-28 12:33:31
# {
#   "timestamp": 1551375211.7781582,
#   "cpuTemp": 57.13,
#   "fan1speed": 2160,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:32
# {
#   "timestamp": 1551375212.274685,
#   "cpuTemp": 57.38,
#   "fan1speed": 2160,
#   "fan2speed": 2002
# }
# 2019-02-28 12:33:33
# {
#   "timestamp": 1551375213.278063,
#   "cpuTemp": 56.69,
#   "fan1speed": 2160,
#   "fan2speed": 1995
# }
# 2019-02-28 12:33:34
# {
#   "timestamp": 1551375214.278052,
#   "cpuTemp": 58.38,
#   "fan1speed": 2160,
#   "fan2speed": 2004
# }
# 2019-02-28 12:33:35
# {
#   "timestamp": 1551375215.278107,
#   "cpuTemp": 59.38,
#   "fan1speed": 2200,
#   "fan2speed": 2043
# }
# 2019-02-28 12:33:36
# {
#   "timestamp": 1551375216.274014,
#   "cpuTemp": 60.06,
#   "fan1speed": 2264,
#   "fan2speed": 2098
# }
# 2019-02-28 12:33:37
# {
#   "timestamp": 1551375217.2741709,
#   "cpuTemp": 59.69,
#   "fan1speed": 2312,
#   "fan2speed": 2147
# }
# 2019-02-28 12:33:38
# {
#   "timestamp": 1551375218.274666,
#   "cpuTemp": 60.63,
#   "fan1speed": 2386,
#   "fan2speed": 2219
# }
# 2019-02-28 12:33:39
# {
#   "timestamp": 1551375219.274875,
#   "cpuTemp": 62.19,
#   "fan1speed": 2461,
#   "fan2speed": 2279
# }
# 2019-02-28 12:33:40
# {
#   "timestamp": 1551375220.27394,
#   "cpuTemp": 61.81,
#   "fan1speed": 2521,
#   "fan2speed": 2329
# }
# 2019-02-28 12:33:41
# {
#   "timestamp": 1551375221.276384,
#   "cpuTemp": 62.56,
#   "fan1speed": 2584,
#   "fan2speed": 2387
# }
# 2019-02-28 12:33:41
# {
#   "timestamp": 1551375221.7731571,
#   "cpuTemp": 62.56,
#   "fan1speed": 2614,
#   "fan2speed": 2419
# }
# 2019-02-28 12:33:42
# {
#   "timestamp": 1551375222.774446,
#   "cpuTemp": 64.0,
#   "fan1speed": 2686,
#   "fan2speed": 2481
# }
# 2019-02-28 12:33:43
# {
#   "timestamp": 1551375223.77564,
#   "cpuTemp": 63.5,
#   "fan1speed": 2741,
#   "fan2speed": 2555
# }
# 2019-02-28 12:33:44
# {
#   "timestamp": 1551375224.7734551,
#   "cpuTemp": 65.19,
#   "fan1speed": 2792,
#   "fan2speed": 2610
# }
# 2019-02-28 12:33:45
# {
#   "timestamp": 1551375225.773279,
#   "cpuTemp": 64.63,
#   "fan1speed": 2865,
#   "fan2speed": 2678
# }
# 2019-02-28 12:33:46
# {
#   "timestamp": 1551375226.773798,
#   "cpuTemp": 66.06,
#   "fan1speed": 2952,
#   "fan2speed": 2740
# }
# 2019-02-28 12:33:47
# {
#   "timestamp": 1551375227.7749388,
#   "cpuTemp": 65.63,
#   "fan1speed": 3016,
#   "fan2speed": 2806
# }
# 2019-02-28 12:33:48
# {
#   "timestamp": 1551375228.774108,
#   "cpuTemp": 67.0,
#   "fan1speed": 3100,
#   "fan2speed": 2855
# }
# 2019-02-28 12:33:49
# {
#   "timestamp": 1551375229.774425,
#   "cpuTemp": 67.38,
#   "fan1speed": 3155,
#   "fan2speed": 2930
# }
# 2019-02-28 12:33:50
# {
#   "timestamp": 1551375230.774813,
#   "cpuTemp": 66.81,
#   "fan1speed": 3259,
#   "fan2speed": 3004
# }
# 2019-02-28 12:33:51
# {
#   "timestamp": 1551375231.773555,
#   "cpuTemp": 68.13,
#   "fan1speed": 3307,
#   "fan2speed": 3069
# }
# 2019-02-28 12:33:52
# {
#   "timestamp": 1551375232.774961,
#   "cpuTemp": 68.44,
#   "fan1speed": 3393,
#   "fan2speed": 3153
# }
# 2019-02-28 12:33:53
# {
#   "timestamp": 1551375233.77373,
#   "cpuTemp": 67.81,
#   "fan1speed": 3479,
#   "fan2speed": 3203
# }
# 2019-02-28 12:33:54
# {
#   "timestamp": 1551375234.773296,
#   "cpuTemp": 69.06,
#   "fan1speed": 3546,
#   "fan2speed": 3322
# }
# 2019-02-28 12:33:55
# {
#   "timestamp": 1551375235.77341,
#   "cpuTemp": 69.31,
#   "fan1speed": 3658,
#   "fan2speed": 3347
# }
# 2019-02-28 12:33:56
# {
#   "timestamp": 1551375236.774497,
#   "cpuTemp": 68.63,
#   "fan1speed": 3701,
#   "fan2speed": 3467
# }
# 2019-02-28 12:33:57
# {
#   "timestamp": 1551375237.7781749,
#   "cpuTemp": 68.88,
#   "fan1speed": 3761,
#   "fan2speed": 3500
# }
# 2019-02-28 12:33:58
# {
#   "timestamp": 1551375238.776094,
#   "cpuTemp": 70.06,
#   "fan1speed": 3847,
#   "fan2speed": 3557
# }
# 2019-02-28 12:33:59
# {
#   "timestamp": 1551375239.7772858,
#   "cpuTemp": 70.31,
#   "fan1speed": 3877,
#   "fan2speed": 3611
# }
# 2019-02-28 12:34:00
# {
#   "timestamp": 1551375240.7747872,
#   "cpuTemp": 69.5,
#   "fan1speed": 3909,
#   "fan2speed": 3646
# }
# 2019-02-28 12:34:01
# {
#   "timestamp": 1551375241.7749188,
#   "cpuTemp": 69.63,
#   "fan1speed": 3941,
#   "fan2speed": 3653
# }
# 2019-02-28 12:34:02
# {
#   "timestamp": 1551375242.775915,
#   "cpuTemp": 69.88,
#   "fan1speed": 3975,
#   "fan2speed": 3684
# }
# 2019-02-28 12:34:03
# {
#   "timestamp": 1551375243.773899,
#   "cpuTemp": 71.0,
#   "fan1speed": 4006,
#   "fan2speed": 3697
# }
# 2019-02-28 12:34:04
# {
#   "timestamp": 1551375244.774109,
#   "cpuTemp": 71.13,
#   "fan1speed": 4039,
#   "fan2speed": 3729
# }
# 2019-02-28 12:34:05
# {
#   "timestamp": 1551375245.775211,
#   "cpuTemp": 71.38,
#   "fan1speed": 4086,
#   "fan2speed": 3754
# }
# 2019-02-28 12:34:06
# {
#   "timestamp": 1551375246.774477,
#   "cpuTemp": 70.5,
#   "fan1speed": 4097,
#   "fan2speed": 3774
# }
# 2019-02-28 12:34:07
# {
#   "timestamp": 1551375247.773453,
#   "cpuTemp": 70.63,
#   "fan1speed": 4110,
#   "fan2speed": 3803
# }
# 2019-02-28 12:34:08
# {
#   "timestamp": 1551375248.773201,
#   "cpuTemp": 70.81,
#   "fan1speed": 4142,
#   "fan2speed": 3855
# }
# 2019-02-28 12:34:09
# {
#   "timestamp": 1551375249.7756019,
#   "cpuTemp": 70.94,
#   "fan1speed": 4166,
#   "fan2speed": 3869
# }
# 2019-02-28 12:34:10
# {
#   "timestamp": 1551375250.773668,
#   "cpuTemp": 72.0,
#   "fan1speed": 4199,
#   "fan2speed": 3894
# }
# 2019-02-28 12:34:11
# {
#   "timestamp": 1551375251.773154,
#   "cpuTemp": 72.0,
#   "fan1speed": 4238,
#   "fan2speed": 3926
# }
# 2019-02-28 12:34:12
# {
#   "timestamp": 1551375252.773258,
#   "cpuTemp": 72.13,
#   "fan1speed": 4279,
#   "fan2speed": 3956
# }
# 2019-02-28 12:34:13
# {
#   "timestamp": 1551375253.776333,
#   "cpuTemp": 72.25,
#   "fan1speed": 4289,
#   "fan2speed": 3988
# }
# 2019-02-28 12:34:14
# {
#   "timestamp": 1551375254.7745159,
#   "cpuTemp": 72.38,
#   "fan1speed": 4318,
#   "fan2speed": 4016
# }
# 2019-02-28 12:34:15
# {
#   "timestamp": 1551375255.776238,
#   "cpuTemp": 71.5,
#   "fan1speed": 4393,
#   "fan2speed": 4044
# }
# 2019-02-28 12:34:16
# {
#   "timestamp": 1551375256.7736971,
#   "cpuTemp": 71.63,
#   "fan1speed": 4405,
#   "fan2speed": 4069
# }
# 2019-02-28 12:34:17
# {
#   "timestamp": 1551375257.773312,
#   "cpuTemp": 71.69,
#   "fan1speed": 4421,
#   "fan2speed": 4100
# }
# 2019-02-28 12:34:18
# {
#   "timestamp": 1551375258.773524,
#   "cpuTemp": 71.81,
#   "fan1speed": 4454,
#   "fan2speed": 4139
# }
# 2019-02-28 12:34:19
# {
#   "timestamp": 1551375259.7737,
#   "cpuTemp": 71.88,
#   "fan1speed": 4483,
#   "fan2speed": 4163
# }
# 2019-02-28 12:34:20
# {
#   "timestamp": 1551375260.7781708,
#   "cpuTemp": 73.0,
#   "fan1speed": 4527,
#   "fan2speed": 4189
# }
# 2019-02-28 12:34:21
# {
#   "timestamp": 1551375261.773485,
#   "cpuTemp": 73.06,
#   "fan1speed": 4548,
#   "fan2speed": 4227
# }
# 2019-02-28 12:34:22
# {
#   "timestamp": 1551375262.7753768,
#   "cpuTemp": 73.13,
#   "fan1speed": 4566,
#   "fan2speed": 4242
# }
# 2019-02-28 12:34:23
# {
#   "timestamp": 1551375263.7744908,
#   "cpuTemp": 73.19,
#   "fan1speed": 4614,
#   "fan2speed": 4272
# }
# 2019-02-28 12:34:24
# {
#   "timestamp": 1551375264.773485,
#   "cpuTemp": 73.25,
#   "fan1speed": 4660,
#   "fan2speed": 4308
# }
# 2019-02-28 12:34:25
# {
#   "timestamp": 1551375265.7766762,
#   "cpuTemp": 73.31,
#   "fan1speed": 4726,
#   "fan2speed": 4332
# }
# 2019-02-28 12:34:26
# {
#   "timestamp": 1551375266.2781281,
#   "cpuTemp": 73.31,
#   "fan1speed": 4727,
#   "fan2speed": 4365
# }
# 2019-02-28 12:34:26
# {
#   "timestamp": 1551375266.775931,
#   "cpuTemp": 73.38,
#   "fan1speed": 4732,
#   "fan2speed": 4404
# }
# 2019-02-28 12:34:27
# {
#   "timestamp": 1551375267.273768,
#   "cpuTemp": 73.38,
#   "fan1speed": 4750,
#   "fan2speed": 4427
# }
# 2019-02-28 12:34:27
# {
#   "timestamp": 1551375267.7782788,
#   "cpuTemp": 73.19,
#   "fan1speed": 4762,
#   "fan2speed": 4421
# }
# 2019-02-28 12:34:28
# {
#   "timestamp": 1551375268.278284,
#   "cpuTemp": 73.19,
#   "fan1speed": 4764,
#   "fan2speed": 4429
# }
# 2019-02-28 12:34:28
# {
#   "timestamp": 1551375268.7782888,
#   "cpuTemp": 72.25,
#   "fan1speed": 4771,
#   "fan2speed": 4443
# }
# 2019-02-28 12:34:29
# {
#   "timestamp": 1551375269.277716,
#   "cpuTemp": 72.25,
#   "fan1speed": 4798,
#   "fan2speed": 4447
# }
# 2019-02-28 12:34:29
# {
#   "timestamp": 1551375269.7782888,
#   "cpuTemp": 70.63,
#   "fan1speed": 4811,
#   "fan2speed": 4454
# }
# 2019-02-28 12:34:30
# {
#   "timestamp": 1551375270.27375,
#   "cpuTemp": 70.63,
#   "fan1speed": 4829,
#   "fan2speed": 4480
# }
# 2019-02-28 12:34:30
# {
#   "timestamp": 1551375270.778292,
#   "cpuTemp": 71.13,
#   "fan1speed": 4837,
#   "fan2speed": 4493
# }
# 2019-02-28 12:34:31
# {
#   "timestamp": 1551375271.2782888,
#   "cpuTemp": 71.13,
#   "fan1speed": 4851,
#   "fan2speed": 4506
# }
# 2019-02-28 12:34:31
# {
#   "timestamp": 1551375271.77828,
#   "cpuTemp": 70.38,
#   "fan1speed": 4874,
#   "fan2speed": 4522
# }
# 2019-02-28 12:34:32
# {
#   "timestamp": 1551375272.278294,
#   "cpuTemp": 70.38,
#   "fan1speed": 4902,
#   "fan2speed": 4542
# }
# 2019-02-28 12:34:32
# {
#   "timestamp": 1551375272.778275,
#   "cpuTemp": 68.94,
#   "fan1speed": 4929,
#   "fan2speed": 4556
# }
# 2019-02-28 12:34:33
# {
#   "timestamp": 1551375273.273767,
#   "cpuTemp": 68.94,
#   "fan1speed": 4955,
#   "fan2speed": 4565
# }
# 2019-02-28 12:34:33
# {
#   "timestamp": 1551375273.7782881,
#   "cpuTemp": 68.5,
#   "fan1speed": 4970,
#   "fan2speed": 4594
# }
# 2019-02-28 12:34:34
# {
#   "timestamp": 1551375274.2782788,
#   "cpuTemp": 68.5,
#   "fan1speed": 4991,
#   "fan2speed": 4621
# }
# 2019-02-28 12:34:34
# {
#   "timestamp": 1551375274.778271,
#   "cpuTemp": 67.88,
#   "fan1speed": 4995,
#   "fan2speed": 4628
# }
# 2019-02-28 12:34:35
# {
#   "timestamp": 1551375275.2782762,
#   "cpuTemp": 67.88,
#   "fan1speed": 5007,
#   "fan2speed": 4654
# }
# 2019-02-28 12:34:35
# {
#   "timestamp": 1551375275.778282,
#   "cpuTemp": 68.44,
#   "fan1speed": 5028,
#   "fan2speed": 4664
# }
# 2019-02-28 12:34:36
# {
#   "timestamp": 1551375276.2737489,
#   "cpuTemp": 68.44,
#   "fan1speed": 5047,
#   "fan2speed": 4679
# }
# 2019-02-28 12:34:36
# {
#   "timestamp": 1551375276.7782788,
#   "cpuTemp": 68.06,
#   "fan1speed": 5128,
#   "fan2speed": 4704
# }
